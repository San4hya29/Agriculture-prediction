# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import warnings
from sklearn import metrics
from sklearn.naive_bayes import GaussianNB
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('D:/Agriprj/Data/crop_recommendation.csv')
data.head()
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label
# 0   89  46  43    20.879744  82.002744  6.502985  202.935536  rice
# 1   66  40  36    21.770462  80.319644  7.038096  226.655537  rice
# 2   75  42  39    23.004459  82.320763  7.840207  263.964248  rice
# 3  100  39  43    26.491096  80.158363  6.980401  242.864034  rice
# 4   86  54  45    20.130175  81.604873  7.628473  262.717340  rice

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot: >

# %%
X = data.drop('label', axis=1)
Y = data['label']

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size = 0.2)

# %%
model = GaussianNB()
model.fit(Xtrain, Ytrain)
# Out:
# GaussianNB()

# %%
predictions = model.predict(Xtest)

# %%
predictions
# Out:
# array(['cotton', 'mothbeans', 'maize', 'pigeonpeas', 'watermelon',
#        'kidneybeans', 'apple', 'orange', 'pigeonpeas', 'watermelon',
#        'mothbeans', 'chickpea', 'grapes', 'grapes', 'maize', 'mango',
#        'blackgram', 'orange', 'jute', 'apple', 'mothbeans', 'mungbean',
#        'mungbean', 'papaya', 'papaya', 'grapes', 'pomegranate', 'coconut',
#        'watermelon', 'coconut', 'jute', 'cotton', 'apple', 'jute',
#        'orange', 'grapes', 'coffee', 'mango', 'pigeonpeas', 'orange',
#        'orange', 'pigeonpeas', 'mungbean', 'papaya', 'pigeonpeas',
#        'mango', 'mungbean', 'chickpea', 'cotton', 'papaya', 'banana',
#        'papaya', 'maize', 'muskmelon', 'jute', 'chickpea', 'banana',
#        'banana', 'maize', 'kidneybeans', 'coffee', 'pigeonpeas',
#        'mungbean', 'chickpea', 'kidneybeans', 'coffee', 'cotton',
#        'kidneybeans', 'mothbeans', 'apple', 'mothbeans', 'papaya',
#        'muskmelon', 'watermelon', 'pigeonpeas', 'rice', 'muskmelon',
#        'kidneybeans', 'apple', 'jute', 'kidneybeans', 'banana', 'apple',
#        'coconut', 'apple', 'lentil', 'rice', 'muskmelon', 'jute',
#        'coconut', 'banana', 'muskmelon', 'watermelon', 'orange', 'cotton',
#        'orange', 'lentil', 'blackgram', 'chickpea', 'banana', 'mango',
#        'kidneybeans', 'rice', 'coconut', 'maize', 'lentil', 'pomegranate',
#        'mothbeans', 'pomegranate', 'banana', 'apple', 'rice', 'muskmelon',
#        'jute', 'coffee', 'watermelon', 'grapes', 'mango', 'coffee',
#        'banana', 'pigeonpeas', 'kidneybeans', 'muskmelon', 'grapes',
#        'mungbean', 'kidneybeans', 'mungbean', 'pigeonpeas', 'watermelon',
#        'apple', 'coffee', 'coffee', 'cotton', 'papaya', 'cotton', 'rice',
#        'cotton', 'papaya', 'mothbeans', 'pomegranate', 'maize', 'papaya',
#        'pigeonpeas', 'grapes', 'cotton', 'coconut', 'rice', 'mungbean',
#        'grapes', 'lentil', 'rice', 'jute', 'orange', 'cotton',
#        'muskmelon', 'watermelon', 'mango', 'lentil', 'coffee',
#        'pomegranate', 'kidneybeans', 'jute', 'pomegranate', 'chickpea',
#        'grapes', 'coconut', 'grapes', 'orange', 'mungbean', 'kidneybeans',
#        'muskmelon', 'lentil', 'coffee', 'mungbean', 'orange', 'coconut',
#        'jute', 'mungbean', 'watermelon', 'pomegranate', 'jute',
#        'blackgram', 'lentil', 'grapes', 'blackgram', 'apple', 'maize',
#        'lentil', 'chickpea', 'pigeonpeas', 'mothbeans', 'mothbeans',
#        'banana', 'pomegranate', 'watermelon', 'muskmelon', 'rice',
#        'muskmelon', 'banana', 'watermelon', 'pomegranate', 'mango',
#        'watermelon', 'coconut', 'kidneybeans', 'mothbeans', 'maize',
#        'maize', 'grapes', 'mango', 'papaya', 'kidneybeans', 'coffee',
#        'muskmelon', 'pigeonpeas', 'pomegranate', 'cotton', 'mungbean',
#        'chickpea', 'banana', 'grapes', 'banana', 'orange', 'muskmelon',
#        'blackgram', 'muskmelon', 'mango', 'mungbean', 'maize',
#        'mothbeans', 'cotton', 'jute', 'coconut', 'pomegranate', 'papaya',
#        'grapes', 'grapes', 'apple', 'coffee', 'muskmelon', 'mungbean',
#        'pigeonpeas', 'pigeonpeas', 'kidneybeans', 'mango', 'chickpea',
#        'apple', 'coconut', 'jute', 'mango', 'blackgram', 'papaya',
#        'watermelon', 'grapes', 'apple', 'lentil', 'banana', 'mungbean',
#        'muskmelon', 'banana', 'jute', 'kidneybeans', 'coconut',
#        'chickpea', 'kidneybeans', 'mungbean', 'pomegranate', 'jute',
#        'grapes', 'banana', 'grapes', 'rice', 'mungbean', 'orange',
#        'maize', 'papaya', 'grapes', 'jute', 'maize', 'maize', 'coconut',
#        'rice', 'banana', 'maize', 'lentil', 'chickpea', 'muskmelon',
#        'mungbean', 'pigeonpeas', 'pigeonpeas', 'apple', 'rice',
#        'mothbeans', 'lentil', 'mothbeans', 'chickpea', 'jute', 'banana',
#        'watermelon', 'kidneybeans', 'coffee', 'muskmelon', 'maize',
#        'apple', 'apple', 'cotton', 'jute', 'muskmelon', 'grapes',
#        'lentil', 'coffee', 'banana', 'mango', 'maize', 'kidneybeans',
#        'coffee', 'kidneybeans', 'lentil', 'mothbeans', 'cotton', 'cotton',
#        'mothbeans', 'jute', 'blackgram', 'kidneybeans', 'orange',
#        'chickpea', 'muskmelon', 'grapes', 'watermelon', 'mothbeans',
#        'muskmelon', 'mango', 'grapes', 'kidneybeans', 'mothbeans',
#        'mango', 'mango', 'kidneybeans', 'orange', 'chickpea', 'mango',
#        'papaya', 'coconut', 'pomegranate', 'jute', 'orange', 'pigeonpeas',
#        'watermelon', 'lentil', 'rice', 'pigeonpeas', 'mothbeans', 'maize',
#        'banana', 'mothbeans', 'kidneybeans', 'mungbean', 'papaya',
#        'cotton', 'blackgram', 'grapes', 'banana', 'blackgram', 'rice',
#        'pigeonpeas', 'kidneybeans', 'pigeonpeas', 'pomegranate',
#        'kidneybeans', 'mango', 'jute', 'papaya', 'mungbean', 'cotton',
#        'banana', 'coffee', 'orange', 'pigeonpeas', 'cotton', 'watermelon',
#        'maize', 'coconut', 'blackgram', 'watermelon', 'mothbeans',
#        'papaya', 'coffee', 'chickpea', 'pigeonpeas', 'apple', 'cotton',
#        'maize', 'banana', 'papaya', 'kidneybeans', 'orange', 'muskmelon',
#        'grapes', 'kidneybeans', 'muskmelon', 'orange', 'coconut',
#        'kidneybeans', 'mango', 'chickpea', 'mango', 'grapes', 'apple',
#        'mungbean', 'cotton', 'jute', 'orange', 'banana', 'orange',
#        'kidneybeans', 'grapes', 'rice', 'apple', 'lentil', 'coffee',
#        'orange', 'maize', 'coconut', 'apple', 'chickpea', 'apple',
#        'orange', 'lentil', 'mango', 'mango', 'banana', 'cotton',
#        'blackgram', 'apple', 'watermelon', 'rice', 'jute', 'cotton',
#        'rice'], dtype='<U11')

# %%
error = metrics.accuracy_score(Ytest,predictions)

# %%
error
# Out:
# 0.9954545454545455
